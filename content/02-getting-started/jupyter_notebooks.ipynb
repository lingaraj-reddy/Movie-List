# %% [markdown]
# <a href="https://colab.research.google.com/github/lingaraj-reddy/Movie-List/blob/main/content/02-getting-started/jupyter_notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mini project on student palcement

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Import Dataset

# %%
df = pd.read_csv('/content/student_placement_dataset (1).csv')

# %%
df.head()
# Out:
#   Student_ID  CGPA  Internships  Projects  Aptitude_Score  \
# 0      S1000  7.11            3         5              74
# 1      S1001  9.59            3         4              51
# 2      S1002  8.65            2         6              64
# 3      S1003  8.07            0         7              91
# 4      S1004  6.17            3         3              98
#
#    Communication_Score  Attendance_Percentage Placement_Status
# 0                   88                     66           Placed
# 1                   52                     62           Placed
# 2                   72                     82           Placed
# 3                   73                     77           Placed
# 4                   80                     97           Placed

# %%
df.shape
# Out:
# (200, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Student_ID             200 non-null    object
#  1   CGPA                   200 non-null    float64
#  2   Internships            200 non-null    int64
#  3   Projects               200 non-null    int64
#  4   Aptitude_Score         200 non-null    int64
#  5   Communication_Score    200 non-null    int64
#  6   Attendance_Percentage  200 non-null    int64
#  7   Placement_Status       200 non-null    object
# dtypes: float64(1), int64(5), object(2)
# memory usage: 12.6+ KB

# %%
plt.scatter(df['CGPA'],df['Projects'], c=df['Communication_Score'])

# %%
x
# Out:
#      Internships  Projects  Aptitude_Score  Communication_Score  \
# 0              3         5              74                   88
# 1              3         4              51                   52
# 2              2         6              64                   72
# 3              0         7              91                   73
# 4              3         3              98                   80
# ..           ...       ...             ...                  ...
# 195            3         3              65                   84
# 196            0         2              64                   65
# 197            2         7              61                   53
# 198            3         5              98                   98
# 199            1         5              66                   95
#
#      Attendance_Percentage
# 0                       66
# 1                       62
# 2                       82
# 3                       77
# 4                       97
# ..                     ...
# ...

# %%
y
# Out:
# 0      Placed
# 1      Placed
# 2      Placed
# 3      Placed
# 4      Placed
#         ...
# 195    Placed
# 196    Placed
# 197    Placed
# 198    Placed
# 199    Placed
# Name: Placement_Status, Length: 200, dtype: object

# %%
y.shape
# Out:
# (200,)

# %% [markdown]
# # train test split

# %%
from sklearn.model_selection  import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#      Internships  Projects  Aptitude_Score  Communication_Score  \
# 178            1         6              95                   75
# 185            2         5              95                   86
# 70             0         7              49                   41
# 104            2         1              60                   49
# 61             0         6              75                   96
# ..           ...       ...             ...                  ...
# 79             3         6              97                   73
# 150            0         4              89                   61
# 33             3         7              56                   84
# 143            1         3              97                   90
# 154            0         3              80                   44
#
#      Attendance_Percentage
# 178                     81
# 185                     72
# 70                      85
# 104                     68
# 61                      63
# ..                     ...
# ...

# %%
x_test
# Out:
#      Internships  Projects  Aptitude_Score  Communication_Score  \
# 123            2         3              40                   94
# 17             1         2              53                   42
# 167            3         5              52                   96
# 75             3         5              84                   99
# 40             0         1              48                   73
# 88             0         2              67                   77
# 85             1         2              40                   73
# 34             3         2              77                   52
# 0              3         5              74                   88
# 184            1         4              94                   54
# 162            2         6              59                   65
# 136            3         1              47                   71
# 23             2         6              68                   49
# 179            1         5              69                   40
# ...

# %%
y_train
# Out:
# 178    Placed
# 185    Placed
# 70     Placed
# 104    Placed
# 61     Placed
#         ...
# 79     Placed
# 150    Placed
# 33     Placed
# 143    Placed
# 154    Placed
# Name: Placement_Status, Length: 160, dtype: object

# %%
y_test
# Out:
# 123        Placed
# 17         Placed
# 167        Placed
# 75         Placed
# 40     Not Placed
# 88         Placed
# 85         Placed
# 34         Placed
# 0          Placed
# 184        Placed
# 162        Placed
# 136        Placed
# 23         Placed
# 179        Placed
# 19         Placed
# 55         Placed
# 63         Placed
# 99         Placed
# 195        Placed
# 180        Placed
# 125        Placed
# 25         Placed
# 37         Placed
# 91         Placed
# 133        Placed
# 48         Placed
# 41         Placed
# 60         Placed
# 87         Placed
# 191        Placed
# 86         Placed
# 152    Not Placed
# 110        Placed
# 95         Placed
# 58         Placed
# 176        Placed
# 65         Placed
# 128    Not Placed
# 93         Placed
# 142        Placed
# Name: Placement_Status, dtype: object

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.47497037,  1.03911568,  1.38036194,  0.39062377,  0.03612768],
#        [ 0.39853836,  0.54282162,  1.38036194,  1.01054967, -0.686426  ],
#        [-1.3484791 ,  1.53540973, -1.27987997, -1.52551085,  0.35726265],
#        [ 0.39853836, -1.4423546 , -0.64373517, -1.07465565, -1.00756097],
#        [-1.3484791 ,  1.03911568,  0.22373502,  1.57411868, -1.40897968],
#        [ 0.39853836, -1.4423546 ,  0.16590367,  1.34869108, -1.32869594],
#        [-0.47497037,  1.03911568, -1.51120536, -0.68015734, -0.52585851],
#        [-0.47497037, -1.4423546 , -1.5690367 ,  0.05248236,  0.91924885],
#        [-0.47497037, -0.94606054, -1.39554266, -1.46915395,  0.75868137],
#        [-1.3484791 , -0.94606054, -1.39554266, -0.79287114, -0.60614226],
#        [-1.3484791 , -1.4423546 ,  1.2068679 , -1.35644015,  1.40095131],
#        [ 0.39853836,  0.54282162, -1.10638594,  0.89783587, -1.08784471],
#        [ 1.27204708, -0.44976649,  1.26469924,  1.74318938, -0.52585851],
# ...

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.39853836, -0.44976649, -1.80036209,  1.46140488,  0.59811388],
#        [-0.47497037, -0.94606054, -1.04855459, -1.46915395, -0.36529103],
#        [ 1.27204708,  0.54282162, -1.10638594,  1.57411868,  0.67839762],
#        [ 1.27204708,  0.54282162,  0.74421713,  1.74318938, -0.20472354],
#        [-1.3484791 , -1.4423546 , -1.33771132,  0.27790997, -1.2484122 ],
#        [-1.3484791 , -0.94606054, -0.23891575,  0.50333757, -1.48926342],
#        [-0.47497037, -0.94606054, -1.80036209,  0.27790997, -0.84699348],
#        [ 1.27204708, -0.94606054,  0.33939771, -0.90558495,  0.99953259],
#        [ 1.27204708,  0.54282162,  0.16590367,  1.12326347, -1.16812845],
#        [-0.47497037,  0.04652757,  1.32253059, -0.79287114,  1.32066756],
#        [ 0.39853836,  1.03911568, -0.70156651, -0.17294524, -1.16812845],
#        [ 1.27204708, -1.4423546 , -1.39554266,  0.16519616, -1.40897968],
#        [ 0.39853836,  1.03911568, -0.1810844 , -1.07465565, -1.48926342],
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
 y_pred = clf.predict(x_test)

# %%
y_test
# Out:
# 123        Placed
# 17         Placed
# 167        Placed
# 75         Placed
# 40     Not Placed
# 88         Placed
# 85         Placed
# 34         Placed
# 0          Placed
# 184        Placed
# 162        Placed
# 136        Placed
# 23         Placed
# 179        Placed
# 19         Placed
# 55         Placed
# 63         Placed
# 99         Placed
# 195        Placed
# 180        Placed
# 125        Placed
# 25         Placed
# 37         Placed
# 91         Placed
# 133        Placed
# 48         Placed
# 41         Placed
# 60         Placed
# 87         Placed
# 191        Placed
# 86         Placed
# 152    Not Placed
# 110        Placed
# 95         Placed
# 58         Placed
# 176        Placed
# 65         Placed
# 128    Not Placed
# 93         Placed
# 142        Placed
# Name: Placement_Status, dtype: object

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.925

# %%
from mlxtend.plotting import plot_decision_regions

# %%
import pickle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
